# %% [markdown]
# <a href="https://colab.research.google.com/github/25021703-TranThuyDuong/Bai-tap-tu-duy-tinh-toan/blob/master/Baitaptuan8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c#W8A1
class Cylinder:
  def __init__(self, bk, cc):
    self.bk = bk
    self.cc = cc
    self.pi = 3.14

  def dientichbemat(self):
    return 2*self.pi*self.bk*self.cc + 2*self.pi*self.bk*self.bk

  def thetich(self):
    return self.pi*self.bk*self.cc*self.cc
a,b = map(int,input().split())
p1 = Cylinder(a,b)
print(p1.dientichbemat())
print(p1.thetich())
# Out:
# 2 3
# 62.8
# 56.519999999999996

# %%
#W8A2
class Date:
  def __init__(self, day, month, year):
    self.day = day
    self.month = month
    self.year = year

  def is_leap_year(self):
    if self.year % 400 == 0 or (self.year % 4 == 0 and self.year % 100 != 0):
      return True
    else:
      return False

  def is_valid(self):
    if self.month < 1 or self.month > 12:
      return False
    days_in_month = [31, 29 if is_leap_year(self.year) else 28,/
                     31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    if self.day < 1 or self.day > days_in_month[self.month - 1]:
      return False
    return True

  def next_day(self):
    days_in_month = [31, 29 if is_leap_year(self.year) else 28,/
                     31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    self.day += 1
    if self.day > days_in_month[self.month - 1]:
            self.day = 1
            self.month += 1
            if self.month > 12:
                self.month = 1
                self.year += 1

  def format(self):
        return f"{self.day:02d}/{self.month:02d}/{self.year}"

  try:
    d, m, y = map(int, s.split('/'))
    date = Date(d, m, y)

    if not date.is_valid():
        print("INVALID")
    else:
        date.next_date()
        print(date.format())

except:
    print("INVALID")

# %%
class Point:
  def __init__(self, x, y, z):
    self.x = x
    self.y = y
  def goc(self):
    if self.x == 0 and self.y==self.x : print('goc')
    else: print('khong phai goc')
  def truc_tung_hoanh(self):
    if self.x == 0 : print('nam tren truc tung')
    else: print('khong phai nam tren truc tung')
    if or self.y == 0 : print('nam tren truc hoanh')
    else: print('khong phai nam tren truc tung')

x,y = map(int,input().split())
p1 = Point(x,y)
p1.goc()
p1.truc_tung_hoanh()
