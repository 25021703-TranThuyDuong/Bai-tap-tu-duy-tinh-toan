# %% [markdown]
# <a href="https://colab.research.google.com/github/25021703-TranThuyDuong/Bai-tap-tu-duy-tinh-toan/blob/master/Baitaptuan10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#W9A2
lst = []

for i in range(3):
  lst_con = list(map(int,input().split()))
  lst.append(lst_con)
k = int(input())
new = []
for i in lst:
  for j in i:
    new.append(j)

new.sort()
print(new)
print(new[k-1])
# Out:
# 1 2 3 4 5
# 2 3 4 5 6
# 3 4 5 45 56
# 4
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 45, 56]
# 3

# %%
#W9A3
n = list(input())
a = len(n)
for i in range(a):
  n[i] = int(n[i])

for i in range(a):
  min_num = n[i]
  s = -1

  for j in range(i+1,a):
    if i == 0 and n[j] ==  0:
      continue
    if n[j] < s:
      min_num = n[j]
      s = j
  if s != -1:
    n[i],n[s] = n[s],n[i]
    break

# %%
#W9A4
def check(a,b):
  j=0
  for i in a:
    if j < len(b) and i.upper() == b[j]:
      j+=1
    elif i.isupper():
      return "NO"
  return "YES" if j == len(b) else "NO"

a = input()
b = input()
print(check(a,b))
# Out:
# abcD
# ABC
# NO
# YES

# %%
#W9A5
