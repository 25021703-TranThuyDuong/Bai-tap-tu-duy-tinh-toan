# %% [markdown]
# <a href="https://colab.research.google.com/github/25021703-TranThuyDuong/Bai-tap-tu-duy-tinh-toan/blob/master/Baitaptuan11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#W11A1
try:
  a,b=map(int,input().split())
  print(a/b)
except ZeroDivisionError:
  print('Loi chia khong')
# Out:
# 23 0
# Loi chia khong

# %%
#W11A2
try:
  n = int(input())
  my_list=[]
  for i in range(n):
    my_list.append(int(input()))
  print(my_list[n])
except IndexError:
  print('Loi index')
# Out:
# 4
# 3
# 4
# 4
# 4
# Loi index

# %%
#W11A3
def tongbinhphuong(n):
  tong=0
  while n!=0:
    tong+=(n%10)**2
    n//=10
  return tong
try:
  a = int(input())
  check=set()
  while a!=1 and a not in check:
    check.add(a)
    a=tongbinhphuong(a)
  if a==1:
    print('YES')
  else:
    print('NO')


except ValueError:
  print('NO')
# Out:
# 20
# NO

# %%
#W11A4
try:
  a,b= map(int,input().split())

except ValueError:
  print("Vui long nhap so!")
else:
  print(a+b)
finally:
  print("Kết thúc chương trình")
# Out:
# n 8
# Vui long nhap so!
# Kết thúc chương trình

# %%
#W11A5
a = input().split()
lst = []
for x in lst:
  try:
    lst.append(int(x))
  except ValueError:
    print(f"{x} không chuyển được")
    pass
print(lst)

# %%
#W11A6
import math

try:
  x = int(input())
  if x<0:
    raise ValueError
  print(f"{math.sqrt(x):.2f}")
except ValueError:
  print('So am')
# Out:
# -4
# So am

# %%
#W11A7
try:
  age = int(input())
  if age < 0 :
    raise ValueError
  namsinh = 2025-age
  print(namsinh)
except ValueError:
  print('Tuoi khong hop le')
# Out:
# -3
# Tuoi khong hop le

# %%
#W11A8
