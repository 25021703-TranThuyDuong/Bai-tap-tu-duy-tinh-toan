# %% [markdown]
# <a href="https://colab.research.google.com/github/25021703-TranThuyDuong/Bai-tap-tu-duy-tinh-toan/blob/master/Baitaptuan4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bai 1
n = int(input())
s = 0
for i in range(1, n + 1):
    s += i
print(s)

# %%
#Bai 2
def prime(n):
    if (n < 2):
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if (n % i == 0):
            return False
    return True
flag = False
while (not flag):
    n = int(input())
    flag = prime(n)
    print(flag)
# Out:
# 2
# True

# %%
#Bai 3
n = int(input())
gt = 1
for i in range(1, n + 1):
    gt *= i
print(gt)

# %%
#Bai 4
n = abs(int(input()))
s = 0
while (n != 0):
    s += 1
    n //= 10
print(s)

# %%
#Bai 5
n = int(input())
a = list(map(int, input().split()))
print("I've found the meaning of life!" if (42 in a) else "It's a joke!")
# Out:
# 5
# 42 5 65 8 9
# I've found the meaning of life!

# %%
#Bai 6
a, b = map(int, input().split())
d = [1] * (b + 1)
d[0] = d[1] = 0
for i in range(2, b + 1):
    if (d[i]):
        for j in range(i * i, b + 1 , i):
            d[j] = 0
s = 0
for i in range(a, b + 1):
    s += i * d[i]
print(s)

# %%
#Bai 6 (Cách 2)
def prime(n):
    if n<2: return False
    for i in range(2,int(n**0.5)+1):
            if n%i==0 :
                return False
    return True
tong=0
a,b=map(int,input().split())
for i in range(a,b+1):
    if prime(i):
        tong+=i
print(tong)

# %%
#Bai 7
def prime(n):
    if (n < 2):
        return 0
    for i in range(2, int(n ** 0.5) + 1):
        if (n % i == 0):
            return 0
    return 1
n = int(input())
res = 0
for i in range(1, int(n ** 0.5) + 1):
    if (n % i == 0):
        res = max(res, i * prime(i), n // i * prime(n // i))
print(res)

# %%
#Bai 7 (Cách 2)
def prime(n):
    if n < 2 : return False
    for i in range(2,int(n**0.5)+1)  :
        if n%i==0: return False
    return True
n=int(input())
for i in range(n,0,-1):
    if prime(i):
        if n%i==0:
            print("Ước số nguyên tố lớn nhất của n là: ",i)
            break

# %%
#Bai 8
def rev(n):
    x = 0
    while (n > 0):
        x = x * 10 + n % 10
        n //= 10
    return x
n = abs(int(input()))
c = 0
rn = rev(n)
while (n != rn):
    c += 1
    n += rn
    rn = rev(n)
print(c, n)

# %%
#Bai 8 (Cách 2)
n=int(input("Nhap n: "))
count=0
sdn=int(str(n)[::-1])
while n!=sdn:
    count+=1
    n=n+sdn
    sdn=int(str(n)[::-1])
    if sdn==int(str(sdn)[::-1]):
        sdx=sdn
        break

print("so lan: ",count)
print("so doi xung: ", sdx)

# %%
#Bai 9
def f(x):
    d = [0] * 10
    while (x > 0):
        if (d[x % 10]):
            return 0
        d[x % 10] = 1
        x //= 10
    return 1
n = int(input())
n = int(n ** 0.5)
a = [i * i for i in range(1, n + 1) if f(i * i)]
print(a if len(a) else "No Number")

# %%
#Bai9 (cách 2)
def check(x):
    a = str(x)
    if len(set(a)) == len(a):
        return True
    return False

n = int(input("Nhap n: "))
cp=[]
for i in range(1,n+1):
    if i % (i**0.5)==0:
        if check(i):
            cp.append(i)
if len(cp)==0:
    print("no number")
else:
    for x in cp:
        print(x,end=" ")

# %%
#Bai 10
def collatz(n):
    sequence = [n]
    while n != 1:
        if n % 2 == 0:
            n = n // 2
        else:
            n = n * 3 + 1
        sequence.append(n)
    return sequence

n = int(input("Nhập n: "))
max_day = []
a = 1

for i in range(1, n + 1):
    current = collatz(i)
    if len(current) > len(max_day):
        max_day = current
        a = i

print("Độ dài dãy lớn nhất:", len(max_day))
print("Dãy collatz dài nhất là số", a)
print("Dãy:", max_day)

# %%
#Bai 11
def count_even_divisors(n):
    count = 0
    for i in range(2, n + 1, 2):
        if n % i == 0:
            count += 1
    return count
n = int(input("Nhập số nguyên dương n (< 10^6): "))
print("Số lượng ước số chẵn của n là:", count_even_divisors(n))

# %%
#Bai 12
def calculate_total_amount(X, N):
    rate = 0.007
    total = X * ((1 + rate) ** N)
    return int(total)

X = int(input("Nhập số tiền gửi ban đầu (X): "))
N = int(input("Nhập số tháng gửi (N): "))
print("Số tiền rút được sau", N, "tháng là:", calculate_total_amount(X, N))

# %%
#Bai 13
def tonguoc(x):
  tong=0
  for i in range(1,x):
      if x%i==0:
        tong+=i
  return tong
a,b=map(int,input().split())
if tonguoc(a) == b and tonguoc(b)==a :
  print("true")
else:
  print("false")
# Out:
# 1184 1210
# true

# %%
#Bai 14
m,n= map(int,input().split())
if m>n:
  m,n=n,m
for i in range(m+1,1,-1):
  if m%i==0 and n%i==0:
    print("Ước chung lớn nhất của m,n là: ",i)
    break
# Out:
# 100024 1024
# Ước chung lơn nhất của m,n là:  8

# %%
#Bai 15
con,chan=map(int,input().split())
if chan%2!=0:
  print("invalid")
else:
  ga= (4*con-chan)//2
  cho= con-ga
  print(ga,cho)
# Out:
# 36 100
# 22 14

# %%
#Bai 16
for i in range (0,100,2):
  if i%3==0:
    print(i,end=" ")
# Out:
# 0 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %%
#Bai 17
a=int(input())
for j in range(1,10):
    print(f"{a} x {j} = {i*j}")
# Out:
# 8
# 8 x 1 = 9
# 8 x 2 = 18
# 8 x 3 = 27
# 8 x 4 = 36
# 8 x 5 = 45
# 8 x 6 = 54
# 8 x 7 = 63
# 8 x 8 = 72
# 8 x 9 = 81

# %%
#Bai 18
a,b=map(int,input().split())
x=min(a,b)
for i in range(1,x+1):
  if a%i==0 and b%i==0:
    print(i, end=" ")

# %%
#Bai 19
n=int(input())
for i in range(0,n+1,2):
  print(i,end=" ")
# Out:
# 8
# 0 2 4 6 8

# %%
#Bai 20
n = int(input())
N=n
while n % 2 == 0:
  if n/2 == 1: print(f"{N} co dang 2^k"); break
  n=n/2
else: print(f"{n} khong co dang 2^k")
# Out:
# 9
# 9 khong co dang 2^k

# %%
#Bai 21
n = int(input("Nhập n: "))
sum = 0
while n > 0: sum += n % 10; n //= 10; print(sum)

# %%
#Bai 22
n = input("Nhap n: ")
chan = 0
le = 0
for i in n:
  if int(i)%2==0:
    chan += 1
  else:
    le += 1
print("So chu so chan la: ", chan)
print("So chu so le la: ", le)
# Out:
# Nhap n: 485769
# So chu so chan la:  3
# So chu so le la:  3

# %%
#Bai 23
n = int(input())
tong=0
k=0
while tong < n:
  if tong + k+1 >= n: break
  k=k+1
  tong+=k
print(k, tong)
# Out:
# 789
# 39 780

# %%
#Bai 33
n = int(input("Nhập số nguyên: "))
ket_qua = f"{n:,}".replace(",", ".")
print("Kết quả:", ket_qua)
